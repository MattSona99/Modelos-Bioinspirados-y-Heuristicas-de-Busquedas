# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: matplotlib in c:\users\matte\appdata\roaming\python\python313\site-packages (from -r requirements.txt (line 1)) (3.10.7)
# Requirement already satisfied: folium in c:\users\matte\anaconda3\lib\site-packages (from -r requirements.txt (line 2)) (0.20.0)
# Requirement already satisfied: numpy in c:\users\matte\appdata\roaming\python\python313\site-packages (from -r requirements.txt (line 3)) (2.2.6)
# Requirement already satisfied: ipython in c:\users\matte\appdata\roaming\python\python313\site-packages (from -r requirements.txt (line 4)) (9.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\matte\appdata\roaming\python\python313\site-packages (from matplotlib->-r requirements.txt (line 1)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\matte\appdata\roaming\python\python313\site-packages (from matplotlib->-r requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\matte\appdata\roaming\python\python313\site-packages (from matplotlib->-r requirements.txt (line 1)) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\matte\appdata\roaming\python\python313\site-packages (from matplotlib->-r requirements.txt (line 1)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\matte\appdata\roaming\python\python313\site-packages (from matplotlib->-r requirements.txt (line 1)) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\matte\appdata\roaming\python\python313\site-packages (from matplotlib->-r requirements.txt (line 1)) (11.3.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\matte\appdata\roaming\python\python313\site-packages (from matplotlib->-r requirements.txt (line 1)) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\matte\appdata\roaming\python\python313\site-packages (from matplotlib->-r requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: branca>=0.6.0 in c:\users\matte\anaconda3\lib\site-packages (from folium->-r requirements.txt (line 2)) (0.8.2)
# Requirement already satisfied: jinja2>=2.9 in c:\users\matte\appdata\roaming\python\python313\site-packages (from folium->-r requirements.txt (line 2)) (3.1.6)
# Requirement already satisfied: requests in c:\users\matte\anaconda3\lib\site-packages (from folium->-r requirements.txt (line 2)) (2.32.3)
# Requirement already satisfied: xyzservices in c:\users\matte\anaconda3\lib\site-packages (from folium->-r requirements.txt (line 2)) (2022.9.0)
# Requirement already satisfied: colorama in c:\users\matte\appdata\roaming\python\python313\site-packages (from ipython->-r requirements.txt (line 4)) (0.4.6)
# Requirement already satisfied: decorator in c:\users\matte\appdata\roaming\python\python313\site-packages (from ipython->-r requirements.txt (line 4)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers in c:\users\matte\appdata\roaming\python\python313\site-packages (from ipython->-r requirements.txt (line 4)) (1.1.1)
# Requirement already satisfied: jedi>=0.16 in c:\users\matte\appdata\roaming\python\python313\site-packages (from ipython->-r requirements.txt (line 4)) (0.19.2)
# Requirement already satisfied: matplotlib-inline in c:\users\matte\appdata\roaming\python\python313\site-packages (from ipython->-r requirements.txt (line 4)) (0.1.7)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\matte\appdata\roaming\python\python313\site-packages (from ipython->-r requirements.txt (line 4)) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\matte\appdata\roaming\python\python313\site-packages (from ipython->-r requirements.txt (line 4)) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\matte\appdata\roaming\python\python313\site-packages (from ipython->-r requirements.txt (line 4)) (0.6.3)
# Requirement already satisfied: traitlets>=5.13.0 in c:\users\matte\appdata\roaming\python\python313\site-packages (from ipython->-r requirements.txt (line 4)) (5.14.3)
# Requirement already satisfied: wcwidth in c:\users\matte\appdata\roaming\python\python313\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython->-r requirements.txt (line 4)) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\matte\appdata\roaming\python\python313\site-packages (from jedi>=0.16->ipython->-r requirements.txt (line 4)) (0.8.5)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\matte\appdata\roaming\python\python313\site-packages (from jinja2>=2.9->folium->-r requirements.txt (line 2)) (3.0.3)
# Requirement already satisfied: six>=1.5 in c:\users\matte\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 1)) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\matte\anaconda3\lib\site-packages (from requests->folium->-r requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\matte\anaconda3\lib\site-packages (from requests->folium->-r requirements.txt (line 2)) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\matte\anaconda3\lib\site-packages (from requests->folium->-r requirements.txt (line 2)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\matte\anaconda3\lib\site-packages (from requests->folium->-r requirements.txt (line 2)) (2026.1.4)
# Requirement already satisfied: executing>=1.2.0 in c:\users\matte\appdata\roaming\python\python313\site-packages (from stack_data->ipython->-r requirements.txt (line 4)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\matte\appdata\roaming\python\python313\site-packages (from stack_data->ipython->-r requirements.txt (line 4)) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\matte\appdata\roaming\python\python313\site-packages (from stack_data->ipython->-r requirements.txt (line 4)) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sys
import os

directorio_actual = os.getcwd()
abspath = os.path.abspath(os.path.join(directorio_actual, '..'))

if abspath not in sys.path:
    sys.path.append(abspath)

from Practica_1.runner import ejecutar_experimento
from Practica_2.runner import ejecutar_analisis_cajas
from Practica_2.utils import generar_tabla_global

# %% [markdown]
# ### **Experimento 1: Greedy Algorithm**

# %%
# Ejecutar Greedy Algorithm
res_greedy = ejecutar_experimento(
    id_algoritmo='greedy',
    maps=False
)
# Out:
# ============================================================================================================
#  EXPERIMENTACIÓN: GREEDY ALGORITHM
# ============================================================================================================
# | Caso   | Score (Ratio)| Kms     | Entropía | Ev. Media| Ev. Mejor | T. Medio (s) |      Semilla      | Mejor FObj |
# ---------------------------------------------------------------------------------------------------------------------
# | Caso 1 |      1.5485 |   23.68 |  15.2903 |      1.0 |         1 |       0.0001 |               N/A | ratio      |
# | Caso 2 |      1.6087 |   23.77 |  14.7736 |      1.0 |         1 |       0.0001 |               N/A | ratio      |
# | Caso 3 |      2.4834 |   23.24 |   9.3560 |      1.0 |         1 |       0.0001 |               N/A | ratio      |
# ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### **Experimento 2: Local Primer Mejor**

# %%
# Ejecutar Búsqueda Primer Mejor
res_primer_mejor = ejecutar_experimento(
    id_algoritmo='local_primer_mejor',
    max_evals=3000,
    maps=False
)
# Out:
# ============================================================================================================
#  EXPERIMENTACIÓN: BÚSQUEDA LOCAL (PRIMER MEJOR)
# ============================================================================================================
# | Caso   | Score (Ratio)| Kms     | Entropía | Ev. Media| Ev. Mejor | T. Medio (s) |      Semilla      | Mejor FObj |
# ---------------------------------------------------------------------------------------------------------------------
# | Caso 1 |      1.5410 |   23.87 |  15.4872 |    333.6 |       348 |       0.0060 |           4192853 | ratio      |
# | Caso 2 |      1.5801 |   25.03 |  15.8404 |    311.7 |       358 |       0.0056 |            382941 | insatisfac |
# | Caso 3 |      2.1990 |   25.42 |  11.5598 |    377.0 |       382 |       0.0074 |          27849102 | suma_ponde |
# ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### **Experimento 3: GRASP**

# %%
# Ejecutar GRASP (Multiarranque)
res_grasp = ejecutar_experimento(
    id_algoritmo='grasp',
    maps=False
)
# Out:
# ============================================================================================================
#  EXPERIMENTACIÓN: GRASP (MULTIARRANQUE)
# ============================================================================================================
# | Caso   | Score (Ratio)| Kms     | Entropía | Ev. Media| Ev. Mejor | T. Medio (s) |      Semilla      | Mejor FObj |
# ---------------------------------------------------------------------------------------------------------------------
# | Caso 1 |      1.3576 |   20.93 |  15.4210 |   2030.3 |      1893 |       0.0432 |        1842910337 | ratio      |
# | Caso 2 |      1.4377 |   22.69 |  15.7793 |   2104.8 |      2329 |       0.0488 |           4192853 | ratio      |
# | Caso 3 |      2.0116 |   23.42 |  11.6435 |   2609.8 |      2268 |       0.0472 |            382941 | ratio      |
# ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### **Experimento 4: ILS (Iterated Local Search)**

# %%
# Ejecutar ILS (Iterated Local Search)
res_ils = ejecutar_experimento(
    id_algoritmo='ils',
    maps=False
)
# Out:
# ============================================================================================================
#  EXPERIMENTACIÓN: ILS
# ============================================================================================================
# | Caso   | Score (Ratio)| Kms     | Entropía | Ev. Media| Ev. Mejor | T. Medio (s) |      Semilla      | Mejor FObj |
# ---------------------------------------------------------------------------------------------------------------------
# | Caso 1 |      1.3585 |   20.93 |  15.4100 |   1767.6 |      1645 |       0.0306 |          27849102 | ratio_cuad |
# | Caso 2 |      1.4277 |   22.69 |  15.8888 |   1843.2 |      1536 |       0.0325 |            382941 | suma_ponde |
# | Caso 3 |      2.0116 |   23.42 |  11.6435 |   2109.7 |      1911 |       0.0355 |           4192853 | ratio      |
# ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### **Experimento 5: VNS (Variable Neighborhood Search)**

# %%
# Ejecutar VNS (Variable Neighborhood Search)
res_vns = ejecutar_experimento(
    id_algoritmo='vns',
    maps=False
)
# Out:
# ============================================================================================================
#  EXPERIMENTACIÓN: VNS
# ============================================================================================================
# | Caso   | Score (Ratio)| Kms     | Entropía | Ev. Media| Ev. Mejor | T. Medio (s) |      Semilla      | Mejor FObj |
# ---------------------------------------------------------------------------------------------------------------------
# | Caso 1 |      1.3585 |   20.93 |  15.4100 |   1238.7 |      1362 |       0.0212 |          27849102 | ratio      |
# | Caso 2 |      1.4277 |   22.69 |  15.8888 |   1278.9 |      1162 |       0.0215 |          27849102 | ratio_cuad |
# | Caso 3 |      2.0770 |   25.83 |  12.4367 |   1553.0 |      1645 |       0.0262 |        1842910337 | ratio_cuad |
# ---------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### **Tabla Global de Resultados**

# %%
resultados_totales = {
    'Greedy': res_greedy,
    'Primer Mejor': res_primer_mejor,
    'GRASP': res_grasp,
    'ILS': res_ils,
    'VNS': res_vns
}

generar_tabla_global(resultados_totales)
# Out:
#     <style>
#         .tabla-p2 {
#             width: 100%;
#             border-collapse: collapse;
#             font-family: Arial, sans-serif;
#             margin-top: 15px;
#             background-color: #ffffff;
#             color: #000000;
#             font-size: 0.9em;
#         }
#         .tabla-p2 th {
#             background-color: #e0e0e0;
#             color: #000000;
#             font-weight: bold;
#             text-align: center;
#             padding: 8px 4px;
#             border: 1px solid #444;
#         }
#         .tabla-p2 .borde-grueso {
#             border-right: 3px solid #222;
#         }
#         .tabla-p2 td {
#             padding: 8px 4px;
#             text-align: center;
#             border: 1px solid #bbbbbb;
#             color: #111111;
#         }
#         .tabla-p2 td.algo-name {
#             font-weight: bold;
#             background-color: #f5f5f5;
#             border-right: 3px solid #222;
#             border-left: 3px solid #222;
#             text-align: left;
#             padding-left: 10px;
#         }
#         .tabla-p2 tbody tr:last-child td {
#             border-bottom: 3px solid #222;
#         }
#         .tabla-p2 thead tr:first-child th {
#             border-top: 3px solid #222;
#         }
#     </style>
#
#     <h3 style="color: inherit;">Tabla 1.1. Resultados Globales</h3>
#     <table class="tabla-p2">
#         <thead>
#             <tr>
#                 <th rowspan="2" class="borde-grueso" style="border-left: 3px solid #222;">Modelo</th>
#                 <th colspan="4" class="borde-grueso">Caso 1</th>
#                 <th colspan="4" class="borde-grueso">Caso 2</th>
#                 <th colspan="4" class="borde-grueso">Caso 3</th>
#             </tr>
#             <tr>
#     <th>#Ev</th><th>F OBJ</th><th>Kms</th><th class="borde-grueso">Entr</th><th>#Ev</th><th>F OBJ</th><th>Kms</th><th class="borde-grueso">Entr</th><th>#Ev</th><th>F OBJ</th><th>Kms</th><th class="borde-grueso">Entr</th>
#             </tr>
#         </thead>
#         <tbody>
#     <tr><td class="algo-name">Greedy</td><td>1.0</td><td>1.5485</td><td>23.68</td><td class="borde-grueso">15.2903</td><td>1.0</td><td>1.6087</td><td>23.77</td><td class="borde-grueso">14.7736</td><td>1.0</td><td>2.4834</td><td>23.24</td><td class="borde-grueso">9.3560</td></tr>
# <tr><td class="algo-name">P.Mejor</td><td>333.6</td><td>1.5410</td><td>23.87</td><td class="borde-grueso">15.4872</td><td>311.7</td><td>1.5801</td><td>25.03</td><td class="borde-grueso">15.8404</td><td>377.0</td><td>2.1990</td><td>25.42</td><td class="borde-grueso">11.5598</td></tr>
# <tr><td class="algo-name">GRASP</td><td>2030.3</td><td>1.3576</td><td>20.93</td><td class="borde-grueso">15.4210</td><td>2104.8</td><td>1.4377</td><td>22.69</td><td class="borde-grueso">15.7793</td><td>2609.8</td><td>2.0116</td><td>23.42</td><td class="borde-grueso">11.6435</td></tr>
# <tr><td class="algo-name">ILS</td><td>1767.6</td><td>1.3585</td><td>20.93</td><td class="borde-grueso">15.4100</td><td>1843.2</td><td>1.4277</td><td>22.69</td><td class="borde-grueso">15.8888</td><td>2109.7</td><td>2.0116</td><td>23.42</td><td class="borde-grueso">11.6435</td></tr>
# <tr><td class="algo-name">VNS</td><td>1238.7</td><td>1.3585</td><td>20.93</td><td class="borde-grueso">15.4100</td><td>1278.9</td><td>1.4277</td><td>22.69</td><td class="borde-grueso">15.8888</td><td>1553.0</td><td>2.0770</td><td>25.83</td><td class="borde-grueso">12.4367</td></tr>
# </tbody></table>

# %% [markdown]
# ### **Cajas Negras & Caja Blanca**
#
# *Nota: El valor de mejor_fobj_conocido utilizado como referencia para el RPD corresponde al mejor resultado obtenido en la Práctica 1 (con semillas [42, 123, 987, 555, 2024]). Las semillas de la Práctica 2 se actualizaron según indicación del profesor; la comparativa RPD mide la mejora de P2 respecto al mejor histórico de P1.*

# %%
# Caso 1: Mejor Fobj Conocido en Practica 1: Búsqueda Tabú
ejecutar_analisis_cajas(caso_nombre='Caso 1', mejor_fobj_conocido=1.3665)
# Out:
# ================================================================================
#  INICIANDO ANÁLISIS AVANZADO DE CAJA NEGRA Y BLANCA (Caso 1)
# ================================================================================
# Ejecutando algoritmos (5 semillas)... esto puede tardar un momento.
#
# --- 1. MEDIDAS DE CAJA NEGRA ---
# =================================================================
# | Algoritmo  | Media    | Std (σ)  | CV (%)   | RPD (%)  |
# -----------------------------------------------------------------
# | GRASP      | 1.37     | 0.01     | 0.92     | -0.65    |
# | ILS        | 1.49     | 0.09     | 6.08     | -0.00    |
# | VNS        | 1.43     | 0.07     | 4.74     | -0.58    |
# =================================================================
#   ℹ️  RPD negativo detectado vs. fobj_mejor_conocido=1.3665:
#      GRASP obtiene 1.3576 (RPD=-0.65%) — la P2 supera el mejor de P1.
#      VNS obtiene 1.3585 (RPD=-0.58%) — la P2 supera el mejor de P1.
#      Considera actualizar fobj_mejor_conocido al best efectivo de P1 o documentar la mejora.
# --- 2. MEDIDAS DE CAJA BLANCA ---
#
# [2.1] Diversificación Estructural (Hamming/Overlap, prefijo=4):
#   GRASP:
# >> Tasa de Overlap en las primeras 4 posiciones: 25.0%
#    Buena diversificación. El algoritmo explora diferentes inicios de ruta.
#   ILS:
# >> Tasa de Overlap en las primeras 4 posiciones: 22.5%
#    Buena diversificación. El algoritmo explora diferentes inicios de ruta.
#   VNS:
# >> Tasa de Overlap en las primeras 4 posiciones: 7.5%
#    Buena diversificación. El algoritmo explora diferentes inicios de ruta.
#
# [2.2] Profundidad de Estancamiento (Stagnation Depth):
# >> ILS Stagnation Depth (evaluaciones de BL por ciclo, n=55):
#    Media=156.4   σ=67.8   Min=66   Max=316
#    ✓ La BL termina razonablemente rápido, dejando espacio a la mutación.
#
# >> VNS Stagnation Depth (acumulado en 5 ejecuciones):
#    k    | Intentos  | Mejoras  | Tasa éxito | % del total mejoras
#    -----------------------------------------------------------------
#    1    | 20        | 7        | 35.0     % | 63.6               %
#    2    | 12        | 0        | 0.0      % | 0.0                %
#    3    | 11        | 3        | 27.3     % | 27.3               %
#    4    | 7         | 1        | 14.3     % | 9.1                %
#    ✓ Los entornos pequeños (k=1,2) generan el 64% de las mejoras: diversificación gradual eficaz.
#
# [2.3] Estudio comparativo del tamaño de RCL en GRASP:
# ==============================================================================
# | RCL  | Media    | Best     | σ        | CV (%)   | Overlap (%)  |
# ------------------------------------------------------------------------------
# | 3    | 1.3682   | 1.3576   | 0.0126   | 0.92     | 25.0         |
# | 4    | 1.3908   | 1.3766   | 0.0074   | 0.53     | 32.5         |
# | 5    | 1.3613   | 1.3576   | 0.0042   | 0.31     | 40.0         |
# ==============================================================================
# Lectura: RCL=3 (default PDF) tiende a CV bajo y overlap alto (poca diversificación).
# RCL mayor relaja el determinismo del greedy, aumentando la exploración.
#
# Análisis estadístico finalizado.

# %%
# Caso 2: Mejor Fobj Conocido en Practica 1: Enfriamiento Simulado
ejecutar_analisis_cajas(caso_nombre='Caso 2', mejor_fobj_conocido=1.4676)
# Out:
# ================================================================================
#  INICIANDO ANÁLISIS AVANZADO DE CAJA NEGRA Y BLANCA (Caso 2)
# ================================================================================
# Ejecutando algoritmos (5 semillas)... esto puede tardar un momento.
#
# --- 1. MEDIDAS DE CAJA NEGRA ---
# =================================================================
# | Algoritmo  | Media    | Std (σ)  | CV (%)   | RPD (%)  |
# -----------------------------------------------------------------
# | GRASP      | 1.45     | 0.01     | 1.00     | -2.04    |
# | ILS        | 1.54     | 0.10     | 6.39     | -1.96    |
# | VNS        | 1.56     | 0.09     | 5.99     | -2.04    |
# =================================================================
#   ℹ️  RPD negativo detectado vs. fobj_mejor_conocido=1.4676:
#      GRASP obtiene 1.4377 (RPD=-2.04%) — la P2 supera el mejor de P1.
#      ILS obtiene 1.4388 (RPD=-1.96%) — la P2 supera el mejor de P1.
#      VNS obtiene 1.4377 (RPD=-2.04%) — la P2 supera el mejor de P1.
#      Considera actualizar fobj_mejor_conocido al best efectivo de P1 o documentar la mejora.
# --- 2. MEDIDAS DE CAJA BLANCA ---
#
# [2.1] Diversificación Estructural (Hamming/Overlap, prefijo=4):
#   GRASP:
# >> Tasa de Overlap en las primeras 4 posiciones: 35.0%
#    Buena diversificación. El algoritmo explora diferentes inicios de ruta.
#   ILS:
# >> Tasa de Overlap en las primeras 4 posiciones: 12.5%
#    Buena diversificación. El algoritmo explora diferentes inicios de ruta.
#   VNS:
# >> Tasa de Overlap en las primeras 4 posiciones: 12.5%
#    Buena diversificación. El algoritmo explora diferentes inicios de ruta.
#
# [2.2] Profundidad de Estancamiento (Stagnation Depth):
# >> ILS Stagnation Depth (evaluaciones de BL por ciclo, n=55):
#    Media=165.7   σ=77.0   Min=66   Max=385
#    ✓ La BL termina razonablemente rápido, dejando espacio a la mutación.
#
# >> VNS Stagnation Depth (acumulado en 5 ejecuciones):
#    k    | Intentos  | Mejoras  | Tasa éxito | % del total mejoras
#    -----------------------------------------------------------------
#    1    | 21        | 7        | 33.3     % | 77.8               %
#    2    | 11        | 0        | 0.0      % | 0.0                %
#    3    | 10        | 2        | 20.0     % | 22.2               %
#    4    | 8         | 0        | 0.0      % | 0.0                %
#    ✓ Los entornos pequeños (k=1,2) generan el 78% de las mejoras: diversificación gradual eficaz.
#
# [2.3] Estudio comparativo del tamaño de RCL en GRASP:
# ==============================================================================
# | RCL  | Media    | Best     | σ        | CV (%)   | Overlap (%)  |
# ------------------------------------------------------------------------------
# | 3    | 1.4491   | 1.4377   | 0.0144   | 1.00     | 35.0         |
# | 4    | 1.4619   | 1.4603   | 0.0033   | 0.23     | 60.0         |
# | 5    | 1.4531   | 1.4377   | 0.0145   | 1.00     | 30.0         |
# ==============================================================================
# Lectura: RCL=3 (default PDF) tiende a CV bajo y overlap alto (poca diversificación).
# RCL mayor relaja el determinismo del greedy, aumentando la exploración.
#
# Análisis estadístico finalizado.

# %%
# Caso 3: Mejor Fobj Conocido en Practica 1: Busqueda Tabú
ejecutar_analisis_cajas(caso_nombre='Caso 3', mejor_fobj_conocido=2.0265)
# Out:
# ================================================================================
#  INICIANDO ANÁLISIS AVANZADO DE CAJA NEGRA Y BLANCA (Caso 3)
# ================================================================================
# Ejecutando algoritmos (5 semillas)... esto puede tardar un momento.
#
# --- 1. MEDIDAS DE CAJA NEGRA ---
# =================================================================
# | Algoritmo  | Media    | Std (σ)  | CV (%)   | RPD (%)  |
# -----------------------------------------------------------------
# | GRASP      | 2.09     | 0.06     | 3.09     | -0.73    |
# | ILS        | 2.18     | 0.13     | 5.99     | -0.73    |
# | VNS        | 2.21     | 0.09     | 4.23     | 3.37     |
# =================================================================
#   ℹ️  RPD negativo detectado vs. fobj_mejor_conocido=2.0265:
#      GRASP obtiene 2.0116 (RPD=-0.73%) — la P2 supera el mejor de P1.
#      ILS obtiene 2.0116 (RPD=-0.73%) — la P2 supera el mejor de P1.
#      Considera actualizar fobj_mejor_conocido al best efectivo de P1 o documentar la mejora.
# --- 2. MEDIDAS DE CAJA BLANCA ---
#
# [2.1] Diversificación Estructural (Hamming/Overlap, prefijo=4):
#   GRASP:
# >> Tasa de Overlap en las primeras 4 posiciones: 20.0%
#    Buena diversificación. El algoritmo explora diferentes inicios de ruta.
#   ILS:
# >> Tasa de Overlap en las primeras 4 posiciones: 22.5%
#    Buena diversificación. El algoritmo explora diferentes inicios de ruta.
#   VNS:
# >> Tasa de Overlap en las primeras 4 posiciones: 7.5%
#    Buena diversificación. El algoritmo explora diferentes inicios de ruta.
#
# [2.2] Profundidad de Estancamiento (Stagnation Depth):
# >> ILS Stagnation Depth (evaluaciones de BL por ciclo, n=55):
#    Media=177.8   σ=81.1   Min=78   Max=433
#    ✓ La BL termina razonablemente rápido, dejando espacio a la mutación.
#
# >> VNS Stagnation Depth (acumulado en 5 ejecuciones):
#    k    | Intentos  | Mejoras  | Tasa éxito | % del total mejoras
#    -----------------------------------------------------------------
#    1    | 23        | 9        | 39.1     % | 64.3               %
#    2    | 11        | 1        | 9.1      % | 7.1                %
#    3    | 10        | 3        | 30.0     % | 21.4               %
#    4    | 6         | 1        | 16.7     % | 7.1                %
#    ✓ Los entornos pequeños (k=1,2) generan el 71% de las mejoras: diversificación gradual eficaz.
#
# [2.3] Estudio comparativo del tamaño de RCL en GRASP:
# ==============================================================================
# | RCL  | Media    | Best     | σ        | CV (%)   | Overlap (%)  |
# ------------------------------------------------------------------------------
# | 3    | 2.0926   | 2.0116   | 0.0648   | 3.09     | 20.0         |
# | 4    | 2.0863   | 2.0116   | 0.0643   | 3.08     | 17.5         |
# | 5    | 2.1275   | 2.0563   | 0.0511   | 2.40     | 20.0         |
# ==============================================================================
# Lectura: RCL=3 (default PDF) tiende a CV bajo y overlap alto (poca diversificación).
# RCL mayor relaja el determinismo del greedy, aumentando la exploración.
#
# Análisis estadístico finalizado.
